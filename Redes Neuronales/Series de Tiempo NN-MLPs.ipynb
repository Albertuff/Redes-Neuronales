# %% [markdown]
# <hr style="color:blue">
#
# # <span style="color:cyan"><center> Series de Tiempo con Redes Neuronales
#  En este script vamos a ver como resolvemos dos problemas:
#   - 1.- Estandarización de los datos: Es útil transformar los datos a una escala de (0,1) o bien a (-1,1).
#
#   - 2.- Estacionariedad de los datos: Al menos débilmente estacionaria. Esto es, que tenga media y varianza constantes, es decir, que no cambie en el tiempo.
#
# Comenzaremos pro resolver el problema 2 y así será más fácil resolver 1.
#
# <hr style="color:blue">

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Flatten
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("PG.csv")
data.head()
# Out:
#          Date       Close
# 0  01/02/2019   98.550003
# 1  01/03/2019  104.050003
# 2  01/04/2019  106.480003
# 3  01/05/2019  102.910004
# 4  01/06/2019  109.650002

# %% [markdown]
# ### <span style="color:cyan"> Tranformaremos la serie para que sea debilmente estacionaria.
#
# Una transforación útil es: Aplicar logaritmos a la serie y despues calcular la primera diferencia.
#
# Digamos que el valor de la serie en el tiempo t es: y(t)
#  - Ln_Y = ln(y(t))
#
#  - D(t) = Ln_Y(t) - Ln_Y(t-1) = aprox. igual a [ [ y(t) - y(t-1) ] / y(t-1) ] *100 = Variación porcentual

# %%
data_diff=np.log(data.Close) - np.log(data.Close.shift(periods=1))
data_diff
# Out:
# 0          NaN
# 1     0.054308
# 2     0.023086
# 3    -0.034102
# 4     0.063439
# 5     0.073730
# 6     0.018383
# 7     0.033935
# 8     0.001045
# 9    -0.019873
# 10    0.023001
# 11   -0.002244
# 12   -0.095848
# 13   -0.028941
# 14    0.069102
# 15   -0.016682
# 16    0.031002
# 17    0.092211
# 18    0.053529
# 19    0.004760
# 20   -0.013691
# 21    0.012828
# 22    0.001942
# 23   -0.081811
# 24   -0.037186
# 25    0.091971
# 26   -0.014953
# 27    0.010661
# 28    0.000593
# 29    0.052689
# 30    0.001124
# 31   -0.018357
# 32    0.022562
# 33    0.011058
# 34    0.123469
# 35   -0.019320
# 36   -0.028832
# 37   -0.020021
# 38    0.049476
# 39   -0.082204
# 40   -0.028047
# 41   -0.034528
# 42   -0.007007
# 43   -0.088555
# 44    0.064563
# 45    0.102192
# 46    0.015962
# 47   -0.062482
# 48   -0.034439
# 49    0.077803
# 50    0.023463
# Name: Close, dtype: float64

# %%
data["Var"]=data_diff   # Creamos una columna para la variacion conceptual
data.head(10)
# Out:
#          Date       Close       Var
# 0  01/02/2019   98.550003       NaN
# 1  01/03/2019  104.050003  0.054308
# 2  01/04/2019  106.480003  0.023086
# 3  01/05/2019  102.910004 -0.034102
# 4  01/06/2019  109.650002  0.063439
# 5  01/07/2019  118.040001  0.073730
# 6  01/08/2019  120.230003  0.018383
# 7  01/09/2019  124.379997  0.033935
# 8  01/10/2019  124.510002  0.001045
# 9  01/11/2019  122.059998 -0.019873

# %%
plt.plot(data["Date"],data["Var"]*100)
plt.title("Variación mensual del precio al cierre del mes de la acción P&G de 2019 a 2023")
plt.xticks(np.arange(0,52,12),["2019","2020","2021","2022","2023"], rotation=30,ha="right")
plt.xlabel("Mes y Año")
plt.ylabel("Variación Porcentual en el precio")
plt.grid()

# %%
# Vmaos a darle formato a la serie de tiempo:

# Cuántas observaciones tenemos?
n_obs = len(data) - 1   # El menos uno es debido a que perdimos una observacion al aplicar una diferencia.
n_obs
# Out:
# 50

# %%
# Dividimos el conjunto de datos en entrenamiento y prueba:
n_train = int(n_obs*0.8)    # Tomamos el 80% de los datos para entrenar
train = np.array(data.Var[1:n_train+1]).reshape(-1,1)
test = np.array(data.Var[n_train+1:]).reshape(-1,1)
test
# Out:
# array([[-0.03452758],
#        [-0.00700745],
#        [-0.08855475],
#        [ 0.06456326],
#        [ 0.10219226],
#        [ 0.01596199],
#        [-0.062482  ],
#        [-0.0344394 ],
#        [ 0.07780344],
#        [ 0.02346323]])

# %%
# Preprocesamiento de los datos

# Reescalamos los datos al intervalo (0,1):
from sklearn.preprocessing import MinMaxScaler

escala = MinMaxScaler()
train = escala.fit_transform(train)
test = escala.transform(test)

# %%
# Construimos los atributos (features) y el target:

# Rezago: Es el número de obsevaciones anteriores que vamos a emplear para la predicción dle siguiente.
def crear_dataset(data,rezago):
    X,Y=[],[]
    for i in range(len(data)-rezago):
        a=data[i:(i+rezago)]
        X.append(a)
        Y.append(data[i+rezago])
    return(np.array(X), np.array(Y))

# %%
# Vamos a crear el X_train,X_test,Y_train,Y_test
rezago=1
X_train,Y_train = crear_dataset(train,rezago)
X_test,Y_test = crear_dataset(test,rezago)

# %%
Y_test
# Out:
# array([[0.40507783],
#        [0.03325414],
#        [0.73141214],
#        [0.90298559],
#        [0.50980945],
#        [0.15213567],
#        [0.27999888],
#        [0.79178219],
#        [0.54401217]])

# %%
# Arquitectura de la red neuronal
modelo=Sequential()
modelo.add(Dense(units=50,input_dim=rezago,activation="relu"))
modelo.add(Dense(units=32,activation="relu"))
modelo.add(Dropout(0.3))
modelo.add(Dense(units=1))
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                100
#
#  dense_1 (Dense)             (None, 32)                1632
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,765
# Trainable params: 1,765
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compilar el modelo
modelo.compile(loss="mean_squared_error", optimizer="Adam", metrics="mean_squared_error")

# %%
# Entrenamos el modelo
historial=modelo.fit(X_train,Y_train, epochs=70,batch_size=64,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/70
# 1/1 [==============================] - 1s 806ms/step - loss: 0.2590 - mean_squared_error: 0.2590 - val_loss: 0.2859 - val_mean_squared_error: 0.2859
# Epoch 2/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2449 - mean_squared_error: 0.2449 - val_loss: 0.2775 - val_mean_squared_error: 0.2775
# Epoch 3/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2416 - mean_squared_error: 0.2416 - val_loss: 0.2693 - val_mean_squared_error: 0.2693
# Epoch 4/70
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2279 - mean_squared_error: 0.2279 - val_loss: 0.2613 - val_mean_squared_error: 0.2613
# Epoch 5/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2278 - mean_squared_error: 0.2278 - val_loss: 0.2536 - val_mean_squared_error: 0.2536
# Epoch 6/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2129 - mean_squared_error: 0.2129 - val_loss: 0.2463 - val_mean_squared_error: 0.2463
# Epoch 7/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2125 - mean_squared_error: 0.2125 - val_loss: 0.2394 - val_mean_squared_error: 0.2394
# Epoch 8/70
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2018 - mean_squared_error: 0.2018 - val_loss: 0.2328 - val_mean_squared_error: 0.2328
# Epoch 9/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1902 - mean_squared_error: 0.1902 - val_loss: 0.2264 - val_mean_squared_error: 0.2264
# Epoch 10/70
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1820 - mean_squared_error: 0.1820 - val_loss: 0.2201 - val_mean_squared_error: 0.2201
# Epoch 11/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1813 - mean_squared_error: 0.1813 - val_loss: 0.2140 - val_mean_squared_error: 0.2140
# Epoch 12/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1839 - mean_squared_error: 0.1839 - val_loss: 0.2081 - val_mean_squared_error: 0.2081
# Epoch 13/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1676 - mean_squared_error: 0.1676 - val_loss: 0.2023 - val_mean_squared_error: 0.2023
# Epoch 14/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1603 - mean_squared_error: 0.1603 - val_loss: 0.1967 - val_mean_squared_error: 0.1967
# Epoch 15/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1519 - mean_squared_error: 0.1519 - val_loss: 0.1913 - val_mean_squared_error: 0.1913
# Epoch 16/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1442 - mean_squared_error: 0.1442 - val_loss: 0.1859 - val_mean_squared_error: 0.1859
# Epoch 17/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1465 - mean_squared_error: 0.1465 - val_loss: 0.1806 - val_mean_squared_error: 0.1806
# Epoch 18/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1491 - mean_squared_error: 0.1491 - val_loss: 0.1754 - val_mean_squared_error: 0.1754
# Epoch 19/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1316 - mean_squared_error: 0.1316 - val_loss: 0.1703 - val_mean_squared_error: 0.1703
# Epoch 20/70
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1325 - mean_squared_error: 0.1325 - val_loss: 0.1653 - val_mean_squared_error: 0.1653
# Epoch 21/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1353 - mean_squared_error: 0.1353 - val_loss: 0.1604 - val_mean_squared_error: 0.1604
# Epoch 22/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1123 - mean_squared_error: 0.1123 - val_loss: 0.1556 - val_mean_squared_error: 0.1556
# Epoch 23/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1210 - mean_squared_error: 0.1210 - val_loss: 0.1509 - val_mean_squared_error: 0.1509
# Epoch 24/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1100 - mean_squared_error: 0.1100 - val_loss: 0.1464 - val_mean_squared_error: 0.1464
# Epoch 25/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1151 - mean_squared_error: 0.1151 - val_loss: 0.1420 - val_mean_squared_error: 0.1420
# Epoch 26/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1090 - mean_squared_error: 0.1090 - val_loss: 0.1375 - val_mean_squared_error: 0.1375
# Epoch 27/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1047 - mean_squared_error: 0.1047 - val_loss: 0.1332 - val_mean_squared_error: 0.1332
# Epoch 28/70
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1020 - mean_squared_error: 0.1020 - val_loss: 0.1289 - val_mean_squared_error: 0.1289
# Epoch 29/70
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0965 - mean_squared_error: 0.0965 - val_loss: 0.1247 - val_mean_squared_error: 0.1247
# Epoch 30/70
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0924 - mean_squared_error: 0.0924 - val_loss: 0.1208 - val_mean_squared_error: 0.1208
# Epoch 31/70
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0909 - mean_squared_error: 0.0909 - val_loss: 0.1171 - val_mean_squared_error: 0.1171
# Epoch 32/70
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0784 - mean_squared_error: 0.0784 - val_loss: 0.1136 - val_mean_squared_error: 0.1136
# Epoch 33/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0766 - mean_squared_error: 0.0766 - val_loss: 0.1104 - val_mean_squared_error: 0.1104
# Epoch 34/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0684 - mean_squared_error: 0.0684 - val_loss: 0.1075 - val_mean_squared_error: 0.1075
# Epoch 35/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0684 - mean_squared_error: 0.0684 - val_loss: 0.1049 - val_mean_squared_error: 0.1049
# Epoch 36/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0693 - mean_squared_error: 0.0693 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 37/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0689 - mean_squared_error: 0.0689 - val_loss: 0.1005 - val_mean_squared_error: 0.1005
# Epoch 38/70
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0648 - mean_squared_error: 0.0648 - val_loss: 0.0987 - val_mean_squared_error: 0.0987
# Epoch 39/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0705 - mean_squared_error: 0.0705 - val_loss: 0.0971 - val_mean_squared_error: 0.0971
# Epoch 40/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0853 - mean_squared_error: 0.0853 - val_loss: 0.0958 - val_mean_squared_error: 0.0958
# Epoch 41/70
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0670 - mean_squared_error: 0.0670 - val_loss: 0.0947 - val_mean_squared_error: 0.0947
# Epoch 42/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0679 - mean_squared_error: 0.0679 - val_loss: 0.0937 - val_mean_squared_error: 0.0937
# Epoch 43/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0689 - mean_squared_error: 0.0689 - val_loss: 0.0929 - val_mean_squared_error: 0.0929
# Epoch 44/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0670 - mean_squared_error: 0.0670 - val_loss: 0.0923 - val_mean_squared_error: 0.0923
# Epoch 45/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0573 - mean_squared_error: 0.0573 - val_loss: 0.0918 - val_mean_squared_error: 0.0918
# Epoch 46/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0762 - mean_squared_error: 0.0762 - val_loss: 0.0914 - val_mean_squared_error: 0.0914
# Epoch 47/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0757 - mean_squared_error: 0.0757 - val_loss: 0.0911 - val_mean_squared_error: 0.0911
# Epoch 48/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0716 - mean_squared_error: 0.0716 - val_loss: 0.0909 - val_mean_squared_error: 0.0909
# Epoch 49/70
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0720 - mean_squared_error: 0.0720 - val_loss: 0.0908 - val_mean_squared_error: 0.0908
# Epoch 50/70
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0622 - mean_squared_error: 0.0622 - val_loss: 0.0906 - val_mean_squared_error: 0.0906
# Epoch 51/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0526 - mean_squared_error: 0.0526 - val_loss: 0.0905 - val_mean_squared_error: 0.0905
# Epoch 52/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0566 - mean_squared_error: 0.0566 - val_loss: 0.0904 - val_mean_squared_error: 0.0904
# Epoch 53/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.0903 - val_mean_squared_error: 0.0903
# Epoch 54/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0581 - mean_squared_error: 0.0581 - val_loss: 0.0902 - val_mean_squared_error: 0.0902
# Epoch 55/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0595 - mean_squared_error: 0.0595 - val_loss: 0.0901 - val_mean_squared_error: 0.0901
# Epoch 56/70
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0749 - mean_squared_error: 0.0749 - val_loss: 0.0900 - val_mean_squared_error: 0.0900
# Epoch 57/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0805 - mean_squared_error: 0.0805 - val_loss: 0.0898 - val_mean_squared_error: 0.0898
# Epoch 58/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0697 - mean_squared_error: 0.0697 - val_loss: 0.0897 - val_mean_squared_error: 0.0897
# Epoch 59/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0589 - mean_squared_error: 0.0589 - val_loss: 0.0896 - val_mean_squared_error: 0.0896
# Epoch 60/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0641 - mean_squared_error: 0.0641 - val_loss: 0.0894 - val_mean_squared_error: 0.0894
# Epoch 61/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0655 - mean_squared_error: 0.0655 - val_loss: 0.0893 - val_mean_squared_error: 0.0893
# Epoch 62/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0689 - mean_squared_error: 0.0689 - val_loss: 0.0892 - val_mean_squared_error: 0.0892
# Epoch 63/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0647 - mean_squared_error: 0.0647 - val_loss: 0.0891 - val_mean_squared_error: 0.0891
# Epoch 64/70
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0602 - mean_squared_error: 0.0602 - val_loss: 0.0890 - val_mean_squared_error: 0.0890
# Epoch 65/70
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0704 - mean_squared_error: 0.0704 - val_loss: 0.0889 - val_mean_squared_error: 0.0889
# Epoch 66/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0598 - mean_squared_error: 0.0598 - val_loss: 0.0888 - val_mean_squared_error: 0.0888
# Epoch 67/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0695 - mean_squared_error: 0.0695 - val_loss: 0.0888 - val_mean_squared_error: 0.0888
# Epoch 68/70
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0729 - mean_squared_error: 0.0729 - val_loss: 0.0887 - val_mean_squared_error: 0.0887
# Epoch 69/70
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0582 - mean_squared_error: 0.0582 - val_loss: 0.0887 - val_mean_squared_error: 0.0887
# Epoch 70/70
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0772 - mean_squared_error: 0.0772 - val_loss: 0.0887 - val_mean_squared_error: 0.0887

# %%
# Evaluamos el desempeño predictivo del modelo, evaluando el modelo en el conjunto de prueba.
loss_test , mse_test = modelo.evaluate(X_test,Y_test)
print(f"El error cuadratico medio en el conjunto de prueba es: {mse_test:.4}")
# Out:
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0887 - mean_squared_error: 0.0887
# El error cuadratico medio en el conjunto de prueba es: 0.08867

# %%
# Análisis del modelo

# Desempeño de la métrica y de la función de pérdida

mse=historial.history["mean_squared_error"]
val_mse=historial.history["val_mean_squared_error"]
loss=historial.history["loss"]
val_loss=historial.history["val_loss"]
epocas=range(1,len(mse)+1)

plt.plot(epocas, mse, "ob", label="MSE entrenamiento")
plt.plot(epocas, val_mse, "r", label="MSE validación")
plt.title("MSE de entrenamiento vs Validación")
plt.legend()
plt.figure()

plt.plot(epocas, loss, "ob", label="Pérdida entrenamiento")
plt.plot(epocas, val_loss, "r", label="Pérdida validación")
plt.title("Pérdida de entrenamiento vs Validación")
plt.legend()
plt.figure()

# %% [markdown]
# 1Observamos que la red no está sobreentrenada o subentrenada.

# %%
# Hacemos las predicciones:
Y_pred = modelo.predict(X_test)
Y_pred  # Estas son las predicciones de los datos reescalados
# Out:
# 1/1 [==============================] - 0s 69ms/step
# array([[0.3624477 ],
#        [0.4158712 ],
#        [0.24849738],
#        [0.55229044],
#        [0.623979  ],
#        [0.45969817],
#        [0.30655566],
#        [0.3626189 ],
#        [0.5775149 ]], dtype=float32)

# %%
# Para hacer las predicciones de la serie en los valores originales, esto es, las predicciones de los variaciones porcentuales. 
# Entonces tenemos que regresar las predicciones a la escala original.

# Por ejemplo, para rescatar los valores originales a partir de los transformados:
Y_test = escala.inverse_transform(Y_test)
Y_test
# Out:
# array([[-0.00700745],
#        [-0.08855475],
#        [ 0.06456326],
#        [ 0.10219226],
#        [ 0.01596199],
#        [-0.062482  ],
#        [-0.0344394 ],
#        [ 0.07780344],
#        [ 0.02346323]])

# %%
# Enronces, las predicciones de las variaciones porcentuales son:
Y_pred = escala.inverse_transform(modelo.predict(X_test))
Y_pred
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[-0.01635696],
#        [-0.00464028],
#        [-0.04134822],
#        [ 0.0252788 ],
#        [ 0.04100132],
#        [ 0.00497173],
#        [-0.02861505],
#        [-0.01631942],
#        [ 0.03081095]], dtype=float32)

# %%
# La raiz cuadrada del error cuadrático medio es:
np.sqrt(np.mean(Y_pred-Y_test)**2)

# Tenemos un error estandar del 2.5%
# Out:
# 0.010746411287050488

# %%
# Vamos a agregar ahora las predicciones de las variaciones en el conjunto de entrenamiento y prueba al DataFrame, así como los precios al cierre predichos:
data["Var_train"] = np.nan
data.loc[rezago+1:len(X_train)+rezago,"Var_train"] = escala.inverse_transform(modelo.predict(X_train))
data.loc[len(X_train)+2*rezago+1:,"Var_test"] = escala.inverse_transform(modelo.predict(X_test))
data
# Out:
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
#           Date       Close       Var  Var_train  Var_test
# 0   01/02/2019   98.550003       NaN        NaN       NaN
# 1   01/03/2019  104.050003  0.054308        NaN       NaN
# 2   01/04/2019  106.480003  0.023086   0.020994       NaN
# 3   01/05/2019  102.910004 -0.034102   0.007948       NaN
# 4   01/06/2019  109.650002  0.063439  -0.016176       NaN
# 5   01/07/2019  118.040001  0.073730   0.024809       NaN
# 6   01/08/2019  120.230003  0.018383   0.029109       NaN
# 7   01/09/2019  124.379997  0.033935   0.005983       NaN
# 8   01/10/2019  124.510002  0.001045   0.012481       NaN
# 9   01/11/2019  122.059998 -0.019873  -0.001261       NaN
# 10  01/12/2019  124.900002  0.023001  -0.010118       NaN
# 11  01/01/2020  124.620003 -0.002244   0.007913       NaN
# 12  01/02/2020  113.230003 -0.095848  -0.002635       NaN
# 13  01/03/2020  110.000000 -0.028941  -0.044995       NaN
# 14  01/04/2020  117.870003  0.069102  -0.013978       NaN
# 15  01/05/2020  115.919998 -0.016682   0.027175       NaN
# 16  01/06/2020  119.570000  0.031002  -0.008759       NaN
# 17  01/07/2020  131.119995  0.092211   0.011256       NaN
# 18  01/08/2020  138.330002  0.053529   0.036831       NaN
# 19  01/09/2020  138.990005  0.004760   0.020668       NaN
# 20  01/10/2020  137.100006 -0.013691   0.000291       NaN
# 21  01/11/2020  138.869995  0.012828  -0.007486       NaN
# 22  01/12/2020  139.139999  0.001942   0.003662       NaN
# 23  01/01/2021  128.210007 -0.081811  -0.000886       NaN
# 24  01/02/2021  123.529999 -0.037186  -0.038011       NaN
# 25  01/03/2021  135.429993  0.091971  -0.017489       NaN
# 26  01/04/2021  133.419998 -0.014953   0.036730       NaN
# 27  01/05/2021  134.850006  0.010661  -0.008023       NaN
# 28  01/06/2021  134.929993  0.000593   0.002757       NaN
# 29  01/07/2021  142.229996  0.052689  -0.001450       NaN
# 30  01/08/2021  142.389999  0.001124   0.020318       NaN
# 31  01/09/2021  139.800003 -0.018357  -0.001228       NaN
# 32  01/10/2021  142.990005  0.022562  -0.009472       NaN
# 33  01/11/2021  144.580002  0.011058   0.007729       NaN
# 34  01/12/2021  163.580002  0.123469   0.002923       NaN
# 35  01/01/2022  160.449997 -0.019320   0.049891       NaN
# 36  01/02/2022  155.889999 -0.028832  -0.009882       NaN
# 37  01/03/2022  152.800003 -0.020021  -0.013932       NaN
# 38  01/04/2022  160.550003  0.049476  -0.010181       NaN
# 39  01/05/2022  147.880005 -0.082204   0.018975       NaN
# 40  01/06/2022  143.789993 -0.028047  -0.038205       NaN
# 41  01/07/2022  138.910004 -0.034528        NaN       NaN
# 42  01/08/2022  137.940002 -0.007007        NaN -0.016357
# 43  01/09/2022  126.250000 -0.088555        NaN -0.004640
# 44  01/10/2022  134.669998  0.064563        NaN -0.041348
# 45  01/11/2022  149.160004  0.102192        NaN  0.025279
# 46  01/12/2022  151.559998  0.015962        NaN  0.041001
# 47  01/01/2023  142.380005 -0.062482        NaN  0.004972
# 48  01/02/2023  137.559998 -0.034439        NaN -0.028615
# 49  01/03/2023  148.690002  0.077803        NaN -0.016319
# 50  01/04/2023  152.220001  0.023463        NaN  0.030811

# %%
102.91*(1+0.002448)
# Out:
# 103.16192368

# %%
# Vamos a agregar ahora las predicciones de los precios al cierre:
data["Close_train"] = np.nan
for i in range(1,len(data)):
    data.loc[i,"Close_train"] = (1+data.loc[i,"Var_train"])*data.loc[i-1,"Close"]

data["Close_test"] = np.nan
for i in range(1,len(data)):
    data.loc[i,"Close_test"] = (1+data.loc[i,"Var_test"])*data.loc[i-1,"Close"]
    
data
# Out:
#           Date       Close       Var  Var_train  Var_test  Close_train  \
# 0   01/02/2019   98.550003       NaN        NaN       NaN          NaN
# 1   01/03/2019  104.050003  0.054308        NaN       NaN          NaN
# 2   01/04/2019  106.480003  0.023086   0.020994       NaN   106.234391
# 3   01/05/2019  102.910004 -0.034102   0.007948       NaN   107.326326
# 4   01/06/2019  109.650002  0.063439  -0.016176       NaN   101.245341
# 5   01/07/2019  118.040001  0.073730   0.024809       NaN   112.370298
# 6   01/08/2019  120.230003  0.018383   0.029109       NaN   121.476023
# 7   01/09/2019  124.379997  0.033935   0.005983       NaN   120.949378
# 8   01/10/2019  124.510002  0.001045   0.012481       NaN   125.932420
# 9   01/11/2019  122.059998 -0.019873  -0.001261       NaN   124.352975
# 10  01/12/2019  124.900002  0.023001  -0.010118       NaN   120.825004
# 11  01/01/2020  124.620003 -0.002244   0.007913       NaN   125.888302
# 12  01/02/2020  113.230003 -0.095848  -0.002635       NaN   124.291579
# 13  01/03/2020  110.000000 -0.028941  -0.044995       NaN   108.135212
# 14  01/04/2020  117.870003  0.069102  -0.013978       NaN   108.462377
# 15  01/05/2020  115.919998 -0.016682   0.027175       NaN   121.073147
# 16  01/06/2020  119.570000  0.031002  -0.008759       NaN   114.904626
# 17  01/07/2020  131.119995  0.092211   0.011256       NaN   120.915852
# 18  01/08/2020  138.330002  0.053529   0.036831       NaN   135.949252
# 19  01/09/2020  138.990005  0.004760   0.020668       NaN   141.189071
# 20  01/10/2020  137.100006 -0.013691   0.000291       NaN   139.030471
# 21  01/11/2020  138.869995  0.012828  -0.007486       NaN   136.073681
# 22  01/12/2020  139.139999  0.001942   0.003662       NaN   139.378548
# 23  01/01/2021  128.210007 -0.081811  -0.000886       NaN   139.016711
# 24  01/02/2021  123.529999 -0.037186  -0.038011       NaN   123.336567
# 25  01/03/2021  135.429993  0.091971  -0.017489       NaN   121.369633
# 26  01/04/2021  133.419998 -0.014953   0.036730       NaN   140.404404
# 27  01/05/2021  134.850006  0.010661  -0.008023       NaN   132.349567
# 28  01/06/2021  134.929993  0.000593   0.002757       NaN   135.221767
# 29  01/07/2021  142.229996  0.052689  -0.001450       NaN   134.734357
# 30  01/08/2021  142.389999  0.001124   0.020318       NaN   145.119758
# 31  01/09/2021  139.800003 -0.018357  -0.001228       NaN   142.215161
# 32  01/10/2021  142.990005  0.022562  -0.009472       NaN   138.475775
# 33  01/11/2021  144.580002  0.011058   0.007729       NaN   144.095226
# 34  01/12/2021  163.580002  0.123469   0.002923       NaN   145.002581
# 35  01/01/2022  160.449997 -0.019320   0.049891       NaN   171.741248
# 36  01/02/2022  155.889999 -0.028832  -0.009882       NaN   158.864387
# 37  01/03/2022  152.800003 -0.020021  -0.013932       NaN   153.718146
# 38  01/04/2022  160.550003  0.049476  -0.010181       NaN   151.244396
# 39  01/05/2022  147.880005 -0.082204   0.018975       NaN   163.596391
# 40  01/06/2022  143.789993 -0.028047  -0.038205       NaN   142.230303
# 41  01/07/2022  138.910004 -0.034528        NaN       NaN          NaN
# 42  01/08/2022  137.940002 -0.007007        NaN -0.016357          NaN
# 43  01/09/2022  126.250000 -0.088555        NaN -0.004640          NaN
# 44  01/10/2022  134.669998  0.064563        NaN -0.041348          NaN
# 45  01/11/2022  149.160004  0.102192        NaN  0.025279          NaN
# 46  01/12/2022  151.559998  0.015962        NaN  0.041001          NaN
# 47  01/01/2023  142.380005 -0.062482        NaN  0.004972          NaN
# 48  01/02/2023  137.559998 -0.034439        NaN -0.028615          NaN
# 49  01/03/2023  148.690002  0.077803        NaN -0.016319          NaN
# 50  01/04/2023  152.220001  0.023463        NaN  0.030811          NaN
#
#     Close_test
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42  136.637858
# 43  137.299922
# 44  121.029787
# 45  138.074294
# 46  155.275762
# 47  152.313513
# 48  138.305795
# 49  135.315099
# 50  153.271283

# %%
# Gráficas
plt.plot(data.Date,data.Close)
plt.plot(data.Date,data.Close_train)
plt.plot(data.Date,data.Close_test)
plt.xticks(np.arange(0,52,12),["2019","2020","2021","2022","2023"], rotation=30,ha="right")
plt.xlabel("Mes y Año")
plt.ylabel("Variación Porcentual en el precio")
plt.grid()

# %%
# Gráficas
plt.plot(data.Date,data.Var,label="Var")
plt.plot(data.Date,data.Var_train,label="Var_train")
plt.plot(data.Date,data.Var_test,label="Val_test")
plt.xticks(np.arange(0,52,12),["2019","2020","2021","2022","2023"], rotation=30,ha="right")
plt.xlabel("Mes y Año")
plt.ylabel("Variación Porcentual en el precio")
plt.grid()
plt.legend()

# %%
# Como hacemos las predicciones.
# Lo que el modelo predice son las variaciones.
# Como solo tenemos un rezago :

# La última variación observada es:
y = data.Var[n_obs].reshape(-1,1)
y = escala.transform(y)
y_predichos = escala.inverse_transform(modelo.predict(y))
y_predichos     # Variacion porcentual
close_pred = (1+y_predichos)*data.Close[n_obs]
y_predichos, close_pred
# Out:
# 1/1 [==============================] - 0s 47ms/step
# (array([[0.00810597]], dtype=float32), array([[153.45389]], dtype=float32))
